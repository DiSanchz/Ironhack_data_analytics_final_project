SQRT69_corujeraref = [28.416970422314606,-16.459774750724762,28.392408568148394,-16.50105394746396]
SQRT70_caletillas = [28.406357574994033,-16.308620693570646,28.357223254775906,-16.39117908704904]
SQRT71_hoyafria = [28.451494746593117,-16.271198513394864,28.402381359723055,-16.353756906873258]
SQRT72_guajara = [28.472027890065483,-16.289680725139277,28.447478812946464,-16.330959921878474]
SQRT73_mina = [28.471261530784624,-16.322972885520528,28.446712275662893,-16.364252082259725]
SQRT74_araya = [28.374385202572487,-16.38391635445379,28.362100053040407,-16.404555952823387]
SQRT75_refespe = [28.444095800167535,-16.34403091704951,28.41954023808441,-16.385310113788705]
SQRT76_jimenez = [28.497076620236605,-16.262129058755733,28.472533363618872,-16.30340825549493]
SQRT77_mainsc = [28.473237553660304,-16.250112762369014,28.448688757519474,-16.29139195910821]
SQRT78_sc_coast = [28.489825004593707,-16.16854318332189,28.440727559552192,-16.251101576800285]
SQRT79_ifara = [28.48399254667628,-16.246507263756115,28.471720343196653,-16.267146862125713]
#]

# %%
def coordinator(lista4):
    cuadrado = []
    '''dados 2 puntos de latitud y 2 de longitud devuelve las 4 combinaciones psoibles'''
    listaA = []
    listaB = []
    listaC = []
    listaD = []
    listaA.append(lista4[0])
    listaA.append(lista4[1])
    listaB.append(lista4[0])
    listaB.append(lista4[3])
    listaC.append(lista4[2])
    listaC.append(lista4[1])
    listaD.append(lista4[2])
    listaD.append(lista4[3])
    cuadrado.append(listaA)
    cuadrado.append(listaB)
    cuadrado.append(listaC)
    cuadrado.append(listaD)
    
    return cuadrado

# %%
SQRT1 = coordinator(SQR1_palmmar)
SQRT2 = coordinator(SQR2_teno)
SQRT3 = coordinator(SQR3_taganana)
SQRT4 = coordinator(SQR4_teide)
SQRT5 = coordinator(SQR5_sanjdlr)
SQRT6 = coordinator(SQR6_tenosjdlr)
SQRT7 = coordinator(SQR7_loscris)
SQRT8 = coordinator(SQR8_loscris2)
SQRT9 = coordinator(SQR9_loscris3)
SQRT10 = coordinator(SQR10_lasamsur)
SQRT11 = coordinator(SQR11_chayofa)
SQRT12 = coordinator(SQR12_marino)
SQRT13 = coordinator(SQR13_leftoverA)
SQRT14 = coordinator(SQR14_LA)
SQRT15 = coordinator(SQR15_troya)
SQRT16 = coordinator(SQR16_siam)
SQRT17 = coordinator(SQR17_arona)
SQRT18 = coordinator(SQR18_eugenio)
SQRT19 = coordinator(SQR19_fañabe1)
SQRT20 = coordinator(SQR20_leftoverB)
SQRT21 = coordinator(SQR21_elduque)
SQRT22 = coordinator(SQR22_torviscas)
SQRT23 = coordinator(SQR23_miraverde)
SQRT24 = coordinator(SQR24_adeje)
SQRT25 = coordinator(SQR25_vilaflor)
SQRT26 = coordinator(SQR26_tijocoalto)
SQRT27 = coordinator(SQR27_playaparaiso)
SQRT28 = coordinator(SQR28_wildc)
SQRT29 = coordinator(SQR29_wildc2)
SQRT30 = coordinator(SQR30_PSJ) 
SQRT31 = coordinator(SQR31_guialosgig)
SQRT32 = coordinator(SQR32_larena)
SQRT33 = coordinator(SQR33_losgig1)
SQRT34 = coordinator(SQR34_losgig2)
SQRT35 = coordinator(SQR35_santiago)
SQRT36 = coordinator(SQR36_benitez)
SQRT37 = coordinator(SQR37_elfraile)
SQRT38 = coordinator(SQR38_guzaref)
SQRT39 = coordinator(SQR39_silencio)
SQRT40 = coordinator(SQR40_abrigos_tej)
SQRT41 = coordinator(SQR41_isidro)
SQRT42 = coordinator(SQR42_costabona)
SQRT43 = coordinator(SQR43_hidalgo)
SQRT44 = coordinator(SQR44_grandillaref)
SQRT45 = coordinator(SQR45_amarilla)
SQRT46 = coordinator(SQR46_golfsur)
SQRT47 = coordinator(SQR47_aerosur)
SQRT48 = coordinator(SQR48_atogo)
SQRT49 = coordinator(SQR49_medano1)
SQRT50 = coordinator(SQR50_medano2)
SQRT51 = coordinator(SQR51_garachico)
SQRT52 = coordinator(SQR52_bosque)
SQRT53 = coordinator(SQR53_arico)
SQRT54 = coordinator(SQR54_guican)
SQRT55 = coordinator(SQR55_oroalta)
SQRT56 = coordinator(SQR56_realejos)
SQRT57 = coordinator(SQR57_lance)
SQRT58 = coordinator(SQR58_puerto1)
SQRT59 = coordinator(SQR59_midpuerto)
SQRT60 = coordinator(SQR60_puerto3)
SQRT61 = coordinator(SQR61_puertocosta)
SQRT62 = coordinator(SQR62_puerto5)
SQRT63 = coordinator(SQR63_rincon)
SQRT64 = coordinator(SQR64_aguamansa)
SQRT65 = coordinator(SQR65_santaursula)
SQRT66 = coordinator(SQR66_ll)
SQRT67 = coordinator(SQR67_tacoronte)
SQRT68 = coordinator(SQRT68_ag)
SQRT69 = coordinator(SQRT69_corujeraref)
SQRT70 = coordinator(SQRT70_caletillas)
SQRT71 = coordinator(SQRT71_hoyafria)
SQRT72 = coordinator(SQRT72_guajara)
SQRT73 = coordinator(SQRT73_mina)
SQRT74 = coordinator(SQRT74_araya)
SQRT75 = coordinator(SQRT75_refespe)
SQRT76 = coordinator(SQRT76_jimenez)
SQRT77 = coordinator(SQRT77_mainsc)
SQRT78 = coordinator(SQRT78_sc_coast)
SQRT79 = coordinator(SQRT79_ifara)

# %%
#print(SQRT2)
#print(SQRT15)

# %%
tnf = folium.Map(
    location=[28.273007, -16.640793])

#SQR1
folium.Rectangle(bounds=[SQRT1], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)  
#SQR2
folium.Rectangle(bounds=[SQRT2], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf) 
#SQR3
folium.Rectangle(bounds=[SQRT3], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf) 
#SQR4
folium.Rectangle(bounds=[SQRT4], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf) 
#SQR5
folium.Rectangle(bounds=[SQRT5], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf) 
#SQR6
folium.Rectangle(bounds=[SQRT6], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf) 
#SQR7
folium.Rectangle(bounds=[SQRT7], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR8
folium.Rectangle(bounds=[SQRT8], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR9
folium.Rectangle(bounds=[SQRT9], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR10
folium.Rectangle(bounds=[SQRT10], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR11 
folium.Rectangle(bounds=[SQRT11], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR12
folium.Rectangle(bounds=[SQRT12], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR13 
folium.Rectangle(bounds=[SQRT13], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR14 
folium.Rectangle(bounds=[SQRT14], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR15 
folium.Rectangle(bounds=[SQRT15], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR16 
folium.Rectangle(bounds=[SQRT16], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR17 
folium.Rectangle(bounds=[SQRT17], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR18 
folium.Rectangle(bounds=[SQRT18], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR19 
folium.Rectangle(bounds=[SQRT19], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR20 
folium.Rectangle(bounds=[SQRT20], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR21 
folium.Rectangle(bounds=[SQRT21], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR22
folium.Rectangle(bounds=[SQRT22], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR23
folium.Rectangle(bounds=[SQRT23], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR24 
folium.Rectangle(bounds=[SQRT24], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR25 
folium.Rectangle(bounds=[SQRT25], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR26 
folium.Rectangle(bounds=[SQRT26], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR27 
folium.Rectangle(bounds=[SQRT27], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR28      -> COBERTUA SOLO 79% <-
folium.Rectangle(bounds=[SQRT28], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR29 
folium.Rectangle(bounds=[SQRT29], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR30
folium.Rectangle(bounds=[SQRT30], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR31      -> COBERTUA SOLO 77% <- 
folium.Rectangle(bounds=[SQRT31], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR32      -> COBERTUA SOLO 79% <-
folium.Rectangle(bounds=[SQRT32], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR33 
folium.Rectangle(bounds=[SQRT33], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR34 
folium.Rectangle(bounds=[SQRT34], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR35 
folium.Rectangle(bounds=[SQRT35], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR36 
folium.Rectangle(bounds=[SQRT36], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR37 
folium.Rectangle(bounds=[SQRT37], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR38 
folium.Rectangle(bounds=[SQRT38], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR39 
folium.Rectangle(bounds=[SQRT39], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR40 
folium.Rectangle(bounds=[SQRT40], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR41 
folium.Rectangle(bounds=[SQRT41], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR42
folium.Rectangle(bounds=[SQRT42], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR43 
folium.Rectangle(bounds=[SQRT43], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR44 
folium.Rectangle(bounds=[SQRT44], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR45 
folium.Rectangle(bounds=[SQRT45], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR46 
folium.Rectangle(bounds=[SQRT46], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR47 
folium.Rectangle(bounds=[SQRT47], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR48 
folium.Rectangle(bounds=[SQRT48], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR49 
folium.Rectangle(bounds=[SQRT49], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR50 
folium.Rectangle(bounds=[SQRT50], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR51 
folium.Rectangle(bounds=[SQRT51], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR52 
folium.Rectangle(bounds=[SQRT52], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR53 
folium.Rectangle(bounds=[SQRT53], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR54 
folium.Rectangle(bounds=[SQRT54], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR55 
folium.Rectangle(bounds=[SQRT55], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR56 
folium.Rectangle(bounds=[SQRT56], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR57 
folium.Rectangle(bounds=[SQRT57], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR58 
folium.Rectangle(bounds=[SQRT58], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR59 
folium.Rectangle(bounds=[SQRT59], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR60 
folium.Rectangle(bounds=[SQRT60], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR61 
folium.Rectangle(bounds=[SQRT61], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR62 
folium.Rectangle(bounds=[SQRT62], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR63 
folium.Rectangle(bounds=[SQRT63], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR64 
folium.Rectangle(bounds=[SQRT64], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR65 
folium.Rectangle(bounds=[SQRT65], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR66 
folium.Rectangle(bounds=[SQRT66], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR67 
folium.Rectangle(bounds=[SQRT67], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR68 
folium.Rectangle(bounds=[SQRT68], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR69 
folium.Rectangle(bounds=[SQRT69], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR70 
folium.Rectangle(bounds=[SQRT70], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR71 
folium.Rectangle(bounds=[SQRT71], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR72 
folium.Rectangle(bounds=[SQRT72], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR73 
folium.Rectangle(bounds=[SQRT73], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR74 
folium.Rectangle(bounds=[SQRT74], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR75 
folium.Rectangle(bounds=[SQRT75], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR76 
folium.Rectangle(bounds=[SQRT76], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR77 
folium.Rectangle(bounds=[SQRT77], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR78 
folium.Rectangle(bounds=[SQRT78], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)
#SQR79 
folium.Rectangle(bounds=[SQRT79], color='#10ad1d', fill=True, fill_color='#10ad1d', fill_opacity=0.2).add_to(tnf)

# %%
tnf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
