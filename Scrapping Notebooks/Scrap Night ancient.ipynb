# %% [markdown]
# ### Importing libraries and setting up the scrapping tools

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import time 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
import time
import re
import warnings  
warnings.simplefilter('ignore')

opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False   
opciones.add_argument('--start-maximized')         
#opciones.add_argument('user-data-dir=selenium')   
#opciones.add_extension('driver_folder/adblock.crx')       
opciones.add_argument('--incognito')

#driver = "./chromedriver.exe"
#driver = webdriver.Chrome(driver,options = opciones)

# %%
#driver = "./chromedriver.exe"
#driver = webdriver.Chrome(driver,options = opciones)

# %% [markdown]
# ### Loading 150 URLs

# %%
links11 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.514670427251186&ne_lng=-16.371389338624633&sw_lat=28.465586390700444&sw_lng=-16.453947732103027&zoom=13&search_by_map=true']
links12 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.465760344543387&ne_lng=-16.36251528702178&sw_lat=28.416653579999625&sw_lng=-16.445073680500172&zoom=13&search_by_map=true']
links13 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.416970422314606&ne_lng=-16.459774750724762&sw_lat=28.392408568148394&sw_lng=-16.50105394746396&zoom=14&search_by_map=true']
links14 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.406357574994033&ne_lng=-16.308620693570646&sw_lat=28.357223254775906&sw_lng=-16.39117908704904&zoom=13&search_by_map=true']
links15 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.451494746593117&ne_lng=-16.271198513394864&sw_lat=28.402381359723055&sw_lng=-16.353756906873258&zoom=13&search_by_map=true']
links16 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.472027890065483&ne_lng=-16.289680725139277&sw_lat=28.447478812946464&sw_lng=-16.330959921878474&zoom=14&search_by_map=true']
links17 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.471261530784624&ne_lng=-16.322972885520528&sw_lat=28.446712275662893&sw_lng=-16.364252082259725&zoom=14&search_by_map=true']
links18 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.374385202572487&ne_lng=-16.38391635445379&sw_lat=28.362100053040407&sw_lng=-16.404555952823387&zoom=15&search_by_map=true']
links19 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.444095800167535&ne_lng=-16.34403091704951&sw_lat=28.41954023808441&sw_lng=-16.385310113788705&zoom=14&search_by_map=true']
links21 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.497076620236605&ne_lng=-16.262129058755733&sw_lat=28.472533363618872&sw_lng=-16.30340825549493&zoom=14&search_by_map=true']
links22 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.473237553660304&ne_lng=-16.250112762369014&sw_lat=28.448688757519474&sw_lng=-16.29139195910821&zoom=14&search_by_map=true'] 
links23 = ['https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.489825004593707&ne_lng=-16.16854318332189&sw_lat=28.440727559552192&sw_lng=-16.251101576800285&zoom=13&search_by_map=true']
#links24 = ['']
#links25 = ['']
#links26 = ['']
#links27 = ['']
#links28 = ['']
#links29 = ['']



for i in range (20,201,20):
    links11.append(f' https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.514670427251186&ne_lng=-16.371389338624633&sw_lat=28.465586390700444&sw_lng=-16.453947732103027&zoom=13&search_by_map=true&federated_search_session_id=2780749e-ee8a-4dca-abae-dfe8d7551685&pagination_search=true&items_offset={i}&section_offset=3')
for i in range (20,21,20):
    links12.append(f'https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.465760344543387&ne_lng=-16.36251528702178&sw_lat=28.416653579999625&sw_lng=-16.445073680500172&zoom=13&search_by_map=true&federated_search_session_id=2f546d39-293e-4bca-9ac7-d4c7d342faff&pagination_search=true&items_offset={i}&section_offset=3')
#for i in range (20,161,20):
#    links13.append(f'')  
for i in range (20,221,20):                 
    links14.append(f'https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.406357574994033&ne_lng=-16.308620693570646&sw_lat=28.357223254775906&sw_lng=-16.39117908704904&zoom=13&search_by_map=true&federated_search_session_id=3882da14-f938-44ff-a921-22be6282fbfc&pagination_search=true&items_offset={i}&section_offset=3')
for i in range (20,141,20):
    links15.append(f'https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.451494746593117&ne_lng=-16.271198513394864&sw_lat=28.402381359723055&sw_lng=-16.353756906873258&zoom=13&search_by_map=true&federated_search_session_id=34e267ad-f6dd-4cec-8675-62728b1d50ef&pagination_search=true&items_offset={i}&section_offset=3')
#for i in range (20,221,20):
#    links16.append(f'')
#for i in range (20,21,20):
#    links17.append(f'')
#for i in range (20,261,20):
#    links18.append(f'')
#for i in range (20,101,20):
#    links19.append(f'')
#for i in range (20,161,20):
#    links21.append(f'')
for i in range (20,281,20):
    links22.append(f'https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.473237553660304&ne_lng=-16.250112762369014&sw_lat=28.448688757519474&sw_lng=-16.29139195910821&zoom=14&search_by_map=true&federated_search_session_id=a392bcb0-5a4f-42d4-a6f7-770c66c299a7&pagination_search=true&items_offset={i}&section_offset=3')
for i in range (20,121,20):
    links23.append(f'https://www.airbnb.es/s/Tenerife/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=may&date_picker_type=flexible_dates&flexible_trip_lengths%5B%5D=one_week&adults=2&source=structured_search_input_header&search_type=user_map_move&query=Tenerife%2C%20Canary%20Islands%2C%20Spain&ne_lat=28.489825004593707&ne_lng=-16.16854318332189&sw_lat=28.440727559552192&sw_lng=-16.251101576800285&zoom=13&search_by_map=true&federated_search_session_id=14890332-8fa7-4ff5-a97a-ffe5385f52d7&pagination_search=true&items_offset={i}&section_offset=3')
#for i in range (20,141,20):                 
#    links24.append(f'')
#for i in range (20,61,20):
#    links25.append(f'')
#for i in range (20,181,20):
#    links26.append(f'')
#for i in range (20,181,20):
#    links27.append(f'')
#for i in range (20,141,20):
#    links28.append(f'')
#for i in range (20,281,20):
#    links29.append(f'')

# %%
links = [
    links11,
    links12,
    links13,
    links14,
    links15,
    links16,
    links17,
    links18,
    links19,
    links21,
    links22,
    links23]

# %%
len(links22)
# Out:
# 15

# %%
#links26

# %% [markdown]
# ### Initialize dicts

# %%
data = {}
#data1 = {}
#data2 = {}
#data3 = {}
#data4 = {}
#data5 = {}
#data6 = {}
#data7 = {}
#data8 = {}
#data9 = {}
#data10 = {}
report = []

# %% [markdown]
# ### Initialize turbapushka

# %%
def turbapushka(lugar):
    driver = "./chromedriver.exe"
    driver = webdriver.Chrome(driver,options = opciones)
    driver.get(lugar)
    time.sleep(2)
    ###acccept cookies (extended)
    try:
        cookies = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[1]/div/div[3]/section/div[2]/div[2]/button')
        cookies.click()
    except:
        try:
            cookies = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[1]/div/div[2]/section/div[2]/div[2]/button')
            cookies.click()
        except:
            try:
                cookies = driver.find_element_by_xpath('/html/body/div[5]/div/div/div[1]/div/div[2]/section/div[2]/div[2]/button')
            except:
                pass
    
    ### Tab switching and URL getting/scrapping
    
    
    scroll = 0
    elemo = 1
    
    while scroll < 4850:
        for i in range (1,21):
            time.sleep(1)
            driver.execute_script(f"window.scrollTo(0, {scroll})")
            driver.switch_to.window(driver.window_handles[0])
            try:
                room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[4]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[1]/a')
                room.click()
            except:
                try:
                    room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[4]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[2]/a')
                    room.click()
                except:
                    try:
                        room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[5]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[2]/a')
                        room.click()
                    except:
                        try:
                            room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[5]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[1]/a')
                            room.click()
                        except:
                            try:
                                room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[3]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[2]/a')
                                room.click()
                            except:
                                room = driver.find_element_by_xpath(f'//*[@id="site-content"]/div[2]/div/div[3]/div/div/div/div/div/div/div[2]/div/div/div/div/div/div[{elemo}]/div/div/div[2]/div/div/div/div[1]/a')
                                room.click()
            scroll += 250
            elemo += 1
            driver.switch_to.window(driver.window_handles[i])
            
    #get title
            time.sleep(1)
            try:
                time.sleep(1)
                titulo = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[1]/div[1]/div/div/div/div/section/div[1]/span/h1')
            except:
                try:
                    titulo = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[3]/div/div/div/div/section/div[1]/span/h1')
                except:
                    try:
                        titulo = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[3]/div/div/div/div/section/div[1]/span[2]/h1')
                    except:
                        titulo = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[1]/div[1]/div/div/div/div/section/div[1]')
            name = str(titulo.text)
    #get url
            time.sleep(2)
            address = driver.current_url
            identifier = address[28:36]
            
    #get price
            time.sleep(2)
            try:
                precio = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[3]/div/div[2]/div/div/div[1]/div/div/div/div/div/div/div[1]/div[1]/div[1]/div/div/div/span[1]')
            except:
                precio = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[17]/div/div/div/div/div/div/div/div/div[1]/div[1]/div/div/div/span[1]')
            night_cost = str(precio.text)
            
            
    #get basic data
            time.sleep(2)
            try:
                basic_data = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[3]/div/div[1]/div/div[1]/div/div/section/div/div/div/div[1]/ol')
            except: 
                basic_data = driver.find_element_by_xpath('//*[@id="site-content"]/div/div[1]/div[5]/div/div/div/div[2]/section/div/div/ol')
            basics = str(basic_data.text)
            
            
    #get coordinates
            driver.execute_script("window.scrollTo(0, 3500)")
            time.sleep(1)
            elems = driver.find_elements_by_xpath("//a[@href]")
            links = []
            for elem in elems:
                if 'maps' in str(elem.get_attribute("href")):
                    links.append(str(elem.get_attribute("href")))       
            strmap = '-'.join(links)
            coordinates = re.findall('\d{2}\.\d{5}\,\-\d{2}\.\d{5}|\d{2}\.\d{4}\,\-\d{2}\.\d{4}|\d{2}\.\d{5}\,\-\d{2}\.\d{3}', strmap)
            
            data[identifier] = [name, address, basics, coordinates, night_cost]
            
            
            print('######')
            print(identifier)
            print(name)
            print(address)
            print(basics)
            print(coordinates)
            print(night_cost)
            print('######')

# %% [markdown]
# ### Execution

# %%
# links = lista-de-listas
# e = lista
# i = link

cuadrados = 0
for e in links: 
    cuadrados += 1
    counterstrike = 0
    for i in e:
        try:
            turbapushka(i)
            print('pag scrap')
            print(str(counterstrike))
            counterstrike +=1
            report.append(f'scrapping of element {cuadrados} completely succesful')
        except:
            try:
                e = e[counterstrike:]
                turbapushka(i)
                print('pag scrap')
                print(str(counterstrike))
                counterstrike +=1
                report.append(f'scrapping of element {cuadrados} failed twice but was completed')
            except:
                try:
                    e = e[counterstrike:]
                    turbapushka(i)
                    print('pag scrap')
                    print(str(counterstrike))
                    counterstrike +=1
                    report.append(f'scrapping of element {cuadrados} failed twice but was completed')
                except:
                    report.append(f'scrapping of element {cuadrados} failed, partial completion')
                    continue
# Out:
# ######
# 24938138
# Balcón del mar
# https://www.airbnb.es/rooms/24938138?adults=2&children=0&infants=0&check_in=2022-05-30&check_out=2022-06-06&federated_search_id=d54a4c63-fe6a-4658-909a-e06e47dc31ce&source_impression_id=p3_1646565859_rV0q9gpPzDYle9%2FN
# 3 huéspedes · Estudio · 2 camas · 1 baño
# ['28.5026,-16.4254']
# 42€
# ######
# ######
# 51940792
# Surrounded by nature in front the Atlantic Ocean 2
# https://www.airbnb.es/rooms/51940792?adults=2&children=0&infants=0&check_in=2022-05-05&check_out=2022-05-10&federated_search_id=d54a4c63-fe6a-4658-909a-e06e47dc31ce&source_impression_id=p3_1646565871_pkTbKXWbZ3G9Bo63
# 2 huéspedes · 1 dormitorio · 2 camas · 1 baño
# ['28.47853,-16.43751']
# 52€
# ######
# ######
# 10135375
# PARADISE BEACH & POOL, WIFI, VIEWS, TERRACE,GARAGE
# ...

# %%
len(data)
# Out:
# 868

# %%
report
# Out:
# ['scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 1 completely succesful',
#  'scrapping of element 2 completely succesful',
#  'scrapping of element 2 failed, partial completion',
#  'scrapping of element 3 failed, partial completion',
#  'scrapping of element 4 completely succesful',
#  'scrapping of element 4 completely succesful',
#  'scrapping of element 4 completely succesful',
#  'scrapping of element 4 completely succesful',
#  'scrapping of element 4 completely succesful',
# ...

# %%
square_1_A = data

# %%
import pandas as pd

# %%
dfA = pd.DataFrame(square_1_A)

# %%
dfA.T.to_csv('Scrapnight2_67_78.csv')

# %%
dfA.T.tail()
# Out:
#                                                         0  \
# 52492539  Habitación cuádruple en Hotel Atlántico Centro.
# 40463414                                  T3 WESTFALIA TF
# 50862323                           Lagoon 500 Happy Ocean
# 50865713                           Happy Ocean Lagoon 500
# 55364387               Magnifica autocaravana,muy cómoda.
#
#                                                           1  \
# 52492539  https://www.airbnb.es/rooms/52492539?adults=2&...
# 40463414  https://www.airbnb.es/rooms/40463414?adults=2&...
# 50862323  https://www.airbnb.es/rooms/50862323?adults=2&...
# 50865713  https://www.airbnb.es/rooms/50865713?adults=2&...
# 55364387  https://www.airbnb.es/rooms/553643875386600842...
#
#                                                           2  \
# 52492539  4 huéspedes · 1 dormitorio · 2 camas · 1 baño ...
# 40463414     4 huéspedes · 2 dormitorios · 2 camas · 1 baño
# 50862323    4 huéspedes · 2 dormitorios · 2 camas · 2 baños
# ...

# %%
print(dfA.T[3].value_counts())
# Out:
# []                      84
# [28.4188,-16.3028]       4
# [28.5125,-16.3925]       4
# [28.4789,-16.4294]       3
# [28.3626,-16.3744]       2
#                         ..
# [28.3591,-16.3688]       1
# [28.36563,-16.36573]     1
# [28.40388,-16.32944]     1
# [28.36264,-16.36596]     1
# [28.47386,-16.24635]     1
# Name: 3, Length: 772, dtype: int64

# %%
dfA.T.shape
# Out:
# (868, 5)
